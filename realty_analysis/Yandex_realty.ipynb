# %% [markdown]
# #### Иван, привет!
#
# Меня зовут Максим Попов, и я буду проверять твой проект. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов.
#
# ---
#
# Я буду отмечать комментарии цветом и примечанием. В конце заголовка комментария будет указан номер итерации проверки. Пожалуйста, не удаляй и не правь мои комментарии
#
# Критично - требует исправления, влияет на удачное выполнение проекта
#
# Рекомендация - комментарий является рекомендацией или советом. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение
#
# Отлично - Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах
#
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера
# Критично
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера
# Рекомендация
#
# Такой комментарий является рекомендацией или советом. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера
# Отлично
#
# Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Иван, у тебя отличная работа, но следущие моменты нужно подправить:
#
# 1. Анализ зависимости цены и категории этажа
# 2. Анализ факторов, влияющих на цену в центре СПБ
#
# Подробные комментарии по ходу работы
#
# Желтые комментарии-рекомендации на твое усмотрение.
#
# Если есть вопросы ко мне, можешь оставить их в отдельном комментарии
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_2
#
# Иван, привет!
#
# Критичные комментарии не обработаны, доделай, пожалуйста, проект
#
# Подробные комментарии по ходу работы
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Привет, Максим! Извини за то, что заставил делать тебя бесполезную работу. По какой-то причине на платформу подгрузилась нередактированная версия проекта. В отредактированной версии постарался исправить все замечания.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_3
#
# Иван, привет!
#
# Отлично, все критичные комментарии отработаны!
#
# Успеха в дальнейшем обучении!
#
# В качестве анализа влияния факторов на цену по СПБ ты добавил просто матрицу корреляции. Совет на будущее, никогда не стоит опираться на один коэффициет корреляции, зависимости стоит смотреть на визуализациях.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Иван,-привет!" data-toc-modified-id="Иван,-привет!-0.0.0.1">Иван, привет!</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.1">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.2">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.3">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-0.0.4">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_2" data-toc-modified-id="Комментарий-от-ревьюера-v_2-0.0.5">Комментарий от ревьюера v_2</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_3" data-toc-modified-id="Комментарий-от-ревьюера-v_3-0.0.6">Комментарий от ревьюера v_3</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-объявлений-о-продаже-квартир" data-toc-modified-id="Исследование-объявлений-о-продаже-квартир-1">Исследование объявлений о продаже квартир</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.0.1">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1.1">Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1.2">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.3">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2">Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.4">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2.5">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.6">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-1.3">Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3.4">Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.4">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.4">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.5">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_2" data-toc-modified-id="Комментарий-от-ревьюера-v_2-1.4.6">Комментарий от ревьюера v_2</a></span></li><li><span><a href="#Структура" data-toc-modified-id="Структура-1.4.7">Структура</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.8">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.9">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.10">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.11">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.12">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_2" data-toc-modified-id="Комментарий-от-ревьюера-v_2-1.4.13">Комментарий от ревьюера v_2</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.14">Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-1.5">Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.5.1">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-1.6">Чек-лист готовности проекта</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Молодец, что в начале проекте знакомишь с ним, так работа приобретает структуру и лучше воспринимается.
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# На начальном этапе работы над проектом откроем файл и изучим данные, содержащиеся в нем. Это необходимо сделать, чтобы обнаружить, есть ли проблемы в данных, и установить характер проблем. Откроем файл и отобразим случайные 15 строк таблицы.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Все, используемые в проекте библиотеки, следует импортировать в отдельной ячейке
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправлено
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('real_estate_data.csv', sep='\t')
df.sample(15)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 125              20   4800000.0       65.90  2018-02-25T00:00:00      3
# 1429             10   4200000.0       45.30  2017-08-19T00:00:00      2
# 13821             1   3470000.0       37.00  2014-12-10T00:00:00      1
# 16256             3   6860000.0       67.80  2017-04-06T00:00:00      2
# 18534             0   5900000.0       60.00  2017-08-15T00:00:00      3
# 9976              1   4900000.0       59.00  2015-11-12T00:00:00      3
# 22554             5   3415000.0       31.65  2019-04-16T00:00:00      1
# 23331             9   3950000.0       33.90  2017-11-28T00:00:00      1
# 21812             5   4100000.0       57.60  2016-12-21T00:00:00      2
# 14090            14   9500000.0       94.30  2017-04-05T00:00:00      3
# 23396            12   3099000.0       41.00  2017-05-21T00:00:00      1
# 20673            20   7200000.0       58.00  2017-05-01T00:00:00      2
# ...

# %% [markdown]
# При просмотре первых пяти строк уже видны проблемы в данных- пропущенные значения, неверный тип данных, некорректное наименование стобцов. Приведем столбец 'cityCenters_nearest' к "змеиному" регистру. Проверим пропущенные значения в столбцах и изучим данные подробнее методом describe().

# %%
df = df.rename(columns={'cityCenters_nearest': 'city_center_nearest'})
df.info()
df.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Рассчитаем количество отсутствующих значений в столбцах.

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_center_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Отдельно изучим данные в столбце 'locality_name', чтобы проверить наличие неявных повторений в нем.

# %%
df['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# В данных обнаружены проблемы. Массово повторяются населенные пункты, так как они записаны одновременно как 'городской поселок' и как 'поселок городского типа' с чередованием букв 'е' и 'ё'. Город Мурино в части данных записан как 'поселок Мурино' и 'посёлок Мурино', город Кудрово в части данных записан как деревня Кудрово, что также следует исправить.

# %% [markdown]
# ### Вывод

# %% [markdown]
# В качестве вывода приведем анализ информации, содержащейся в столбцах, и дальнейшие пути работы с ней
# * total_images: в столбце приводится информация по количеству фотографий. Данные записаны в правильном формате, пропушенных данных нет;
# * last_price: в столбце приводится информация о последней цене квартиры. Пропущенных данных нет. Цена меняется от 12190 до 763 миллионов рублей. Минимальное значение выглядит подозрительно низким, так как 25-квартильное значение- 3,4 млн рублей.
# * total_area: в столбце указана общая площадь квартиры, указанная вещественным числом, пропусков данных нет;
# * first_day_exposition: в столбце указана дата публикации объявления. Необходимо изменить тип данных и отбросить время публикации, так как во всех строках оно указанно как 00:00:00.
# * rooms: в столбце указано количество комнат. Пропущенных данных нет, изменение типа данных не требуется. В столбце есть 197 нулевых значений;
# * ceiling_height: в столбце указана высотка потолков в квартире. Пропущено 9195 строк. Пропущенные значения можно заполнить в предположении, что одинаковые площади в столбцах 'total_area', 'living_area' и 'kitchen_area' соответствуют типовым квартирам и высота потолка в них тоже одинакова. Значения изменяются от 1 до 100 метров. Оба этих значения не соответствуют действительности, поэтому при дальнейшем анализе, возможно, потребуется отбросить слишком низкие и слишком высокие значения;
# * floors_total: в столбце приводится информация о количестве этажей в доме. Пропущено 86 значений. Пропуски будут заполнены значением -1. Столбец с информацией об этаже необходим для определения, является ли этаж квартиры первым или последним. При введении категориального столбца значения -1 будут выделены в категорию 'неизвестно'. Требуется изменение типа данных на целочисленный. Значения изменяются от 1 до 60, что выглядит логичным;
# * living_area: в столбце приводится жилая площадь квартиры. Пропущено 1903 значения. Пропуски будут заменены средним значением жилой площади для квартир с аналогичной общей площадью. Значения изменяются от 2 до 409,7 м$^2$. Можно допустить существование квартир с такими экстемально низкими и высокими значениями жилой площади. Распределение значений по квартилям выглядит логичным;
# * floor: столбец с информацией об этаже расположения квартиры. Пропущенных данных нет, данные имеют целочисленный формат и значения от 1 до 33, половина из которых не превышает 4;
# * is_apartment: в столбце буллевым значением указано, является ли помещение апартаментами. В данном столбце пропущено наибольшее количество значений- 20924, 2750 имеют значение True и 50- False. При таком количестве недостающих данных столбец не может учитываться при анализе;
# * studio: в столбце буллевым значением указано, является ли квартира студией. Пропущенных данных нет;
# * open_plan: в столбце буллевым значением указано, имеет ли квартира свободную планировку. Пропущенных данных нет;
# * kitchen_area: в столбце указана площадь кухни. Пропущено 2278 значений. Пропуски будут заполнены средним значением площади кухни для квартир с аналогичной общей площадью. Значения изменяются от 1,3 до 112 м$^2$. Можно допустить такие экстремально низкие и высокие значения- распределение по квартилям выглядит логичным, поэтому такие значения практически не влияют на общую статистику;
# * balcony: в столбце указано количество балконов. Пропущено 11519 значений. Необходимо изменить тип данных на целочисленный, а отсутствующие значения заменить нулем в предположении, что при создании объявления количество балконов не указывают при их отсутствии. Однако следует внимательнее подходить к результатам анализа по данному параметру, так как отсутствует около 50% данных;
# * locality_name: в столбце указано название населенного пункта. Необходимо привести все типы населенных пунктов к единому виду, чтобы избежать повторений. Пропущено 49 значений;
# * airports_nearest: в столбце указано расстояние до ближайшего аэропорта. Необходимо изменить тип данных на целочисленный. Пропущено 5542 значения, присутствуют нулевые значения. Судя по карте, вблизи аэропорта Пулково нет населенных пунктов, что исключает  возможность нахождения квартиры в непосредственно близости от аэропорта. Судя по распределению значений по квартилям, нулевые значения- это единичные выбросы. Пропуски и нулевые значения будут заменены на среднее значение расстояния до аэропорта в аналогичном населенном пункте;
# * city_center_nearest: в столбце указано расстояние до центра города. Название столбца было изменено и записано "змеиным" регистром. Тип данных необходимо изменить на целочисленный. Пропущено 5519 значений. Пропуски будут заменены на среднее значение расстояния до центра города в аналогичном населенном пункте;
# * parks_around3000: количество парков в радиусе 3 км от дома. Необходимо изменить тип данных на целочисленный. Пропущено 5518 значений. Можно заполнить отсутствующие данные значением 0 по аналогии с количеством балконов. Есть смысл ввести столбец с буллевым значением наличия парка;
# * parks_nearest: расстояние до ближайшего парка. Необходимо изменить тип данных на целочисленный. Пропущено больше половины значений- 15620;
# * ponds_around3000: количество прудов в радиусе 3 км от дома. Необходимо изменить тип данных на целочисленный. Пропущено 5518 значений. Можно заполнить отсутствующие данные значением 0 по аналогии с количеством балконов. Есть смысл ввести столбец с буллевым значением наличия пруда;
# * ponds_nearest: расстояние до ближайшего пруда. Необходимо изменить тип данных на целочисленный. Пропущено больше половины значений- 14589;
# * days_exposition: количество дней от публикации до снятия объявления. Необходимо изменить тип данных на целочисленный. Пропущено 3181 значение.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Блестящий первый взгляд на данные и составление плана на предобработку 👍🏻
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Исправим данные в столбце с датой публикации объявления и добавим столбец с днем недели публикации.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
df['weekday'] = df['first_day_exposition'].dt.weekday
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    balcony    locality_name  airports_nearest  city_center_nearest  \
# ...

# %% [markdown]
# Заполним пропуски в столбце 'ceiling_height' и проверим количество пропусков в данном столбце после заполнения.

# %%
#заполнение в группировке по одинаковой общей и жилой площади и площади кухни
df_trans = df.groupby(['total_area', 'living_area', 'kitchen_area'])['ceiling_height'].transform('mean')
df['ceiling_height'] = df['ceiling_height'].fillna(df_trans)

#заполнение по одинаковым площадям- общей и кухни
df_trans = df.groupby(['total_area', 'kitchen_area'])['ceiling_height'].transform('mean')
df['ceiling_height'] = df['ceiling_height'].fillna(df_trans)

##заполнение по одинаковым площадям- общей и жилой
df_trans = df.groupby(['total_area', 'living_area'])['ceiling_height'].transform('mean')
df['ceiling_height'] = df['ceiling_height'].fillna(df_trans)

#заполнение по одинаковым площадям- жилой и кухни
df_trans = df.groupby(['kitchen_area', 'living_area'])['ceiling_height'].transform('mean')
df['ceiling_height'] = df['ceiling_height'].fillna(df_trans)

#заполнение по одинаковым площадям- общей
df_trans = df.groupby(['total_area', 'floors_total'])['ceiling_height'].transform('mean')
df['ceiling_height'] = df['ceiling_height'].fillna(df_trans)

#заполнение оставшихся значений мдианным по всему датафрейму
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце 'floors_total' значением -1, чтобы при выделении категории, является ли этаж квартиры первым или последним ввести категорию 'неизвестно'. Заменим тип данных на целочисленный.

# %%
df['floors_total'] = df['floors_total'].fillna(-1).astype('int')
df['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце 'living_area' средним значением жилой площади в квартирах с аналогичной общей площадью.

# %%
df_trans = df.groupby('total_area')['living_area'].transform('mean')
df['living_area'] = df['living_area'].fillna(df_trans)
df['living_area'].isna().sum()
# Out:
# 143

# %% [markdown]
# Большая часть пропусков заполнены. Осталось 143 пропуска. Заполним их следующим образом- возьмем среднее значение отношения жилой площади к общей по всему датафрейму и умножим на него общую площадь квартир.

# %%
#заполним пропуски, умножим общую площадь на среднее отношение жилой площади
#к общей по всему датафрейму
#введем дополнительное условие, чтобы при суммировании по столбцу не учитывалась
#общая площадь квартир с неизвестной жилой площадью
df['living_area'] = df['living_area'].fillna(df['living_area'].sum() / df[df['living_area'].isna() == False]['total_area'].sum())
df['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# По тому же приницпу заполним пропуски в столбце 'kitchen_area'- сначала средней площадью кухни для квартир с аналогичной общей площадью, затем, при необходимости, общей площадью, умноженной на долю площади кухни от общей площади. Дополнительно сгруппируем данные по наличию открытой планировки и по квартирам-студиям, так как площадь кухни в таких квартирах рассчитывается иначе.

# %%
df_trans = df.groupby(['total_area', 'open_plan', 'studio'])['kitchen_area'].transform('mean')
df['kitchen_area'] = df['kitchen_area'].fillna(df_trans)
df['kitchen_area'].isna().sum()
# Out:
# 364

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df['kitchen_area'].sum() / df[df['kitchen_area'].isna() == False]['total_area'].sum())
df['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# При заполнении площади кухни стоило выполнить проверку студий и квартир с открытой планировкой
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправлено.
# </div>

# %% [markdown]
# Заполним пропуски в столбце 'balcony' значением 0 в предположении, что количество балконов не указывают в объявлении при их отсутствии. Заменим тип данных на целочисленный.

# %%
df['balcony'] = df['balcony'].fillna(0).astype('int')
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце 'locality_name' значением 'Неизвестно'.

# %%
df['locality_name'] = df['locality_name'].fillna('Неизвестно')
df['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Приведем типы населенных пунктов к единому виду. Городские поселки и поселки городского типа приведем к единому обозначению, изменим Ё на Е, Мурино и Кудрово запишем одним словом.

# %%
def locality_unification(row):
    locality = str(row['locality_name'])
    return locality.replace('ё', 'е').replace('городской поселок', 'поселок городского типа')
df['locality_name'] = df.apply(locality_unification, axis=1)
df.loc[df['locality_name'] == 'поселок Мурино', 'locality_name'] = 'Мурино'
df.loc[df['locality_name'] == 'деревня Кудрово', 'locality_name'] = 'Кудрово'
df['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Неизвестно',
#        'Никольское', 'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф',
#        'Пикалево', 'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин',
#        'Санкт-Петербург', 'Светогорск', 'Сертолово', 'Сестрорецк',
#        'Сланцы', 'Сосновый Бор', 'Сясьстрой', 'Тихвин', 'Тосно',
#        'Шлиссельбург', 'деревня Агалатово', 'деревня Аро',
#        'деревня Батово', 'деревня Бегуницы', 'деревня Белогорка',
#        'деревня Большая Вруда', 'деревня Большая Пустомержа',
#        'деревня Большие Колпаны', 'деревня Большое Рейзино',
#        'деревня Большой Сабск', 'деревня Бор', 'деревня Борисова Грива',
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Молодец, что обрабатываешт эти значения 👍🏻
#
# </div>

# %% [markdown]
# Заполним отсутствующие значения в столбце 'airport_nearest' средним значением расстояния в аналогичном населенном пункте.

# %%
df_trans = df.groupby('locality_name')['airports_nearest'].transform('mean')
df['airports_nearest'] = df['airports_nearest'].fillna(df_trans)
df['airports_nearest'].isna().sum()
# Out:
# 4830

# %% [markdown]
# По результатам заполнения пустыми осталось еще 4830 строк. Для крупных населенных пунктов можем самостоятельно определить расстояние до аэропорта, пользуясь картами, и заполнить пропуски вручную. В данном случае определены все населенные пункты с количеством записей больше 100.

# %%
df.loc[df['locality_name'] == 'Кудрово', 'airports_nearest'] = 26400
df.loc[df['locality_name'] == 'Всеволожск', 'airports_nearest'] = 46000
df.loc[df['locality_name'] == 'Выборг', 'airports_nearest'] = 155000
df.loc[df['locality_name'] == 'Гатчина', 'airports_nearest'] = 30700
df.loc[df['locality_name'] == 'деревня Новое Девяткино', 'airports_nearest'] = 141000
df.loc[df['locality_name'] == 'Сертолово', 'airports_nearest'] = 61700
df.loc[df['locality_name'] == 'Кириши', 'airports_nearest'] = 154000
df.loc[df['locality_name'] == 'поселок Бугры', 'airports_nearest'] = 48000
df.loc[df['locality_name'] == 'Сланцы', 'airports_nearest'] = 182000
df.loc[df['locality_name'] == 'Волхов', 'airports_nearest'] = 132000
df.loc[df['locality_name'] == 'Кингисепп', 'airports_nearest'] = 127000
df.loc[df['locality_name'] == 'Тосно', 'airports_nearest'] = 50300
df[df['airports_nearest'].isna() == True]['locality_name'].value_counts()
df['airports_nearest'].isna().sum()
# Out:
# 2460

# %% [markdown]
# Таким образом, останется 2460 пропусков. Заполним их значением -1000, чтобы отделить пропущенные значения от существующих при последующем анализе.

# %%
df['airports_nearest'] = df['airports_nearest'].fillna(-1000).astype('int')
df['airports_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропущенные значения в столбце 'city_center_nearest' аналогично расстоянию до аэропорта- в локациях, где более 100 пропусков, заполним вручную, в остальных строках- значением -1000, чтобы отделить от существующих значений и изменим тип данных на целочисленный.

# %%
df.loc[df['locality_name'] == 'Кудрово', 'city_center_nearest'] = 14700
df.loc[df['locality_name'] == 'Всеволожск', 'city_center_nearest'] = 26700
df.loc[df['locality_name'] == 'Выборг', 'city_center_nearest'] = 136000
df.loc[df['locality_name'] == 'Гатчина', 'city_center_nearest'] = 50000
df.loc[df['locality_name'] == 'деревня Новое Девяткино', 'city_center_nearest'] = 21800
df.loc[df['locality_name'] == 'Сертолово', 'city_center_nearest'] = 37000
df.loc[df['locality_name'] == 'Кириши', 'city_center_nearest'] = 168000
df.loc[df['locality_name'] == 'поселок Бугры', 'city_center_nearest'] = 24100
df.loc[df['locality_name'] == 'Сланцы', 'city_center_nearest'] = 187000
df.loc[df['locality_name'] == 'Волхов', 'city_center_nearest'] = 138000
df.loc[df['locality_name'] == 'Кингисепп', 'city_center_nearest'] = 133000
df.loc[df['locality_name'] == 'Тосно', 'city_center_nearest'] = 64000
df['city_center_nearest'] = df['city_center_nearest'].fillna(-1000).astype('int')
df['city_center_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Логичнее бы было заполнить расстояние до центра так, как ты заполняешь расстояние до аэропорта, ведь именно расстояние до центра важно для исследования
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправлено.
# </div>

# %% [markdown]
# Заполним отсутствующие значения в столбце 'parks_around3000' значением 0 в предположении, что количество парков не указывают при их отсутствии, и изменим тип данных на целочисленный.

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(0).astype('int')
df['parks_around3000'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце 'parks_nearest' значением -1, чтобы отделить от существующих значений и изменим тип данных на целочисленный.

# %%
df['parks_nearest'] = df['parks_nearest'].fillna(-1).astype('int')
df['parks_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним отсутствующие значения в столбце 'ponds_around3000' значением 0 в предположении, что количество прудов не указывают при их отсутствии, и изменим тип данных на целочисленный.

# %%
df['ponds_around3000'] = df['ponds_around3000'].fillna(0).astype('int')
df['ponds_around3000'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце 'ponds_nearest' значением -1, чтобы отделить от существующих значений и изменим тип данных на целочисленный.

# %%
df['ponds_nearest'] = df['ponds_nearest'].fillna(-1).astype('int')
df['ponds_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце 'days_exposition' значением -1, чтобы отделить от существующих значений и изменим тип данных на целочисленный.

# %%
df['days_exposition'] = df['days_exposition'].fillna(-1).astype('int')
df['days_exposition'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Отличная обработка пропусков 👍🏻
#
# </div>
# <div class="alert alert-block

# %% [markdown]
# Проверим количество явных дубликатов в данных.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Категоризируем данные. Введем новые столбцы с категориями:
# * is_balcony - буллево значение с отображением, есть ли в квартире балконы;
# * is_walk - буллево значение с отображением, есть ли поблизости места для прогулок- парки и пруды;
# * is_airport - буллево значение с отображением, есть ли поблизости аэропорт. Близким расположением назначим расстояние до аэропорта в 10 км.
# * is_saintp - буллево значение с отображением, находится ли квартира в Санкт-Петербурге или в Ленинградской области.

# %%
df['is_balcony'] = df['balcony'] > 0
df['is_walk'] = ((df['parks_around3000'] > 0) | (df['ponds_around3000'] > 0))
df['is_airport'] = df['airports_nearest'] <= 10000
df['is_saintp'] = df['locality_name'] == 'Санкт-Петербург'
df.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23694             3.7             5    73.300000      3          NaN  ...
# 23695             2.5             5    38.000000      4          NaN  ...
# 23696             3.7             3    29.700000      1          NaN  ...
# 23697             3.0            17     0.573517     12          NaN  ...
# 23698             2.5             5    12.300000      1          NaN  ...
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# ### Вывод
# В результате предварительной подготовки данных были заполнены пропуски в столбцах. В некоторых случаях удалось восстановить данные тем или иным образом, в остальных случаях пропуски были заполнены отрицательными значениями, чтобы отделить их от реальных значений. В нескольких столбцах был изменен тип данных. В данных отсутствуют явные дубликаты. В столбце с названием населенных пунктов были удалены неявные дубликаты путем изменения буквы Ё на Е и изменение типа населенного пункта. Добавлены столбцы с категориальными данными о наличии балконов, мест для прогулки и аэропортов вблизи дома.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Молодец, что не забываешь про вывод 👍🏻
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Для проведения исследовательского анализа данных добавим еще столбцы:
# * meter_price - цена квадратного метра жилья;
# * floor_type - этаж расположения квартиры- первый, последний, другой или неизвестно. Категорию 'неизвестно' укажем для тех домов, в данных которых не была указана этажность и мы приняли ее равной -1;
# * exposition_year - год публикации объявления;
# * exposition_month - месяц публикации объявления;
# * sales_month - месяц продажи квартиры;
# * kitchen_ratio - отношение площади кухни к общей площади квартиры;
# * living_ratio - отношение жилой площади к общей.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Молодец, что в начале шага пишешь план действий
#
# </div>

# %%
df['meter_price'] = df['last_price'] / df['total_area']
df['exposition_year'] = df['first_day_exposition'].dt.year
df['exposition_month'] = df['first_day_exposition'].dt.month
df['kitchen_ratio'] = df['kitchen_area'] / df['total_area']
df['living_ratio'] = df['living_area'] / df['total_area']
df['sales_month'] = (df['first_day_exposition'] + pd.to_timedelta(df['days_exposition'], unit='D')).dt.month
def floor_type(row):
    floor = str(row['floor'])
    a = str(row['floors_total'])
    if floor == '1':
        return 'первый'
    if floor == a:
        return 'последний'
    if a == '-1':
        return 'неизвестно'
    else:
        return 'другой'
df['floor_type'] = df.apply(floor_type, axis=1)
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0        2.700000            16         51.0      8          NaN  ...
# 1        2.650000            11         18.6      1          NaN  ...
# 2        2.666667             5         34.3      4          NaN  ...
# 3        2.650000            14         80.2      9          NaN  ...
# 4        3.030000            14         32.0     13          NaN  ...
#
#    is_walk  is_airport  is_saintp    meter_price exposition_year  \
# 0     True       False       True  120370.370370            2019
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Отлично, все расчеты верны 👍🏻
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Вот этот неизвестный этаж совсем тут не нужен, 86 значений лучше было просто дропнуть
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Здесь я решил оставить эти строки, чтобы использовать в них данные для исследований по другим параметрам. Пока не совсем понимаю, сколько можно данных дропнуть, а сколько- нет :)
# </div>

# %% [markdown]
# ###  Вывод
# В данном разделе в данные были добавлены столбцы для проведения исследовательского анализа данных. Столбец с ценой квадратного метра позволит отбросить слишком низкие значения. Столбцы с отношением площади кухни и жилой площади к общей позволят оценить их корреляцию с ценой квадратного метра и сроком продажи квартиры. Отдельно будет оцениваться, насколько влияет этаж квартиры на срок продажи и цену квадратного метра. Столбцы с годом и месяцем публикации объявления позволят оценить зависимость спроса и предложения во времени. Также добавили столбец с месяцем продажи квартиры, чтобы проверить еще одну гипотезу- что спрос на квартиры зависит от месяца. Так как речь идет о Санкт-Петербурге и окрестностях, можно ожидать, что спрос на квартиры резко возрастает летом в связи с наплывом студентов университетов и туристов, и спадает зимой.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Для начала построим диаграммы размаха, чтобы изучить распределение данных в столбцах. Первой построим диаграмму размаха по столбцу 'last_price', чтобы оценить распределение цен на квартиры.

# %%
df.boxplot(column=['last_price'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# При построении диаграмма размаха обнаружим большое количество выбросов до 200 млн. рублей и единичные выбросы выше. Следует вспомнить, что площадь квартир в столбце 'total_area' доходила до 900 м$^2$. Очевидно, что таких квартир будет крайне мало, а их цена будет высокой, поэтому построим диаграмму размаха по столбцу с ценой квадратного метра.

# %%
df.boxplot(column='meter_price')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Однако и здесь видим большое количество выбросов. Построим гистограмму по столбцу 'last_price' на 50 корзин и значениями от 0 до 200 млн. рублей. При построении отметим, что крайне малый процент величин превышает значение в 20 млн. рублей, поэтому перестроим гистограмму до 20 млн.

# %%
df.hist(column='last_price', bins=50, range=(0, 20000000))
# Out:
# array([[<AxesSubplot:title={'center':'last_price'}>]], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Чтобы избавиться от e-значений используй такую запись:
#
# pd.options.display.float_format = '{:,.1f}'.format
#
# 1 - число разрядов после запятой
#
# </div>

# %% [markdown]
# Видим распределение Пуассона с максимальным значением в районе 3,5 - 4 млн. рублей. Повторим вычисления для цены на квадратный метр.

# %%
df.hist(column='meter_price', bins=100, range=(0, 250000))
# Out:
# array([[<AxesSubplot:title={'center':'meter_price'}>]], dtype=object)

# %% [markdown]
# В случае с ценой квадратного метра видим распределение, близкое к нормальному, и максимальное значение в районе 100 тыс. рублей. Анализируя информацию в этих двух столбцах и изменяя диапазон значений и количество корзин, можем сделать вывод, что количество выбросов небольшое, однако есть слишком низкие значения. Видно, что левый хвост гистограммы перевешивает правый. Это может быть связано как с мошенническими объявлениями, так и с наличием квартир в данных из Санкт-Петербурга и из Ленинградской области- очевидно, что в черте города цена квадратного метра будет выше. Построим и сравним две гистограммы распределения цены квадратного метра- для Санкт-Петербурга и Ленинградской области, используя столбец 'is_saintp'.

# %%
ax = (df
    .query('is_saintp == True')
    .plot(
    kind='hist',
    y='meter_price',
    histtype='step',
    range=(0, 250000),
    bins=50,
    linewidth=5,
    alpha=0.7,
    label='Санкт-Петербург',
    figsize=(12, 9)
))
(df
    .query('is_saintp == False')
    .plot(
    kind='hist',
    y='meter_price',
    histtype='step',
    range=(0, 250000),
    bins=50,
    linewidth=5,
    alpha=0.7,
    label='Ленинградская область',
    ax=ax,
    grid=True,
    legend=True,
    figsize=(12, 9)
) )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Видно, что гистограммы цен в Санкт-Петербурге и области располагаются в разных диапазонах- нетипично низкие значения цены (60 тыс. рублей за квадратный метр) в Санкт-Петербурге являются наиболее популярными для Ленинградской области. В связи с тем, что подавляющее большинство предложений находятся в Санкт-Петербурге, максимум гистограммы для данной локации остался на прежнем месте- в районе 100 тыс. рублей за квадратный метр.
#
# Изучим распределение значений общей площади квартир и проанализируем редкие и выбивающиеся значения.

# %%
df.hist('total_area', bins=100, range=(0,200), figsize=(12, 9))
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %% [markdown]
# На гистограмме четко выделяется несколько пиков- 28 м$^2$, 48 м$^2$, 56 м$^2$, 72 м$^2$ и 78 м$^2$. Это можно объяснить количеством комнат в квартире- для однокомнатных типичное значение площади будет намного меньше, чем у трехкомнатных. Построим отдельно гистограммы для количества комнат в квартирах- 1, 2, 3, 4 и более.

# %%
ax = (df
        .query('rooms == 1')
        .plot(y='total_area', 
              kind='hist', 
              bins=100, 
              range=(15, 200), 
              alpha=0.5, 
              figsize=(12, 9), 
              grid=True, 
              label='Однокомнатные'))
(df
   .query('rooms == 2')
   .plot(y='total_area', 
         kind='hist', 
         bins=100, 
         range=(15, 200), 
         alpha=0.5, 
         figsize=(12, 9), 
         grid=True, 
         ax=ax, 
         label='Двухкомнатные'))
(df
   .query('rooms > 2')
   .plot(y='total_area', 
         kind='hist', 
         bins=100, 
         range=(15, 200), 
         alpha=0.5, 
         figsize=(12, 9), 
         grid=True, 
         ax=ax, 
         label='Три и более'))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Здесь видим, что для однокомнатных квартир пиковые значения находятся в диапазоне от 28 до 32 м$^2$. Это можно объяснить требованиями строительных норм (СП 54.13330.2016, табл. 5.1), согласно которым минимальная площадь однокомнатной квартиры не может быть ниже 28 м$^2$. Этим же объясняются пики для двухкомнатных квартир в районе 44 м$^2$, для трехкомнатных и более- в районе 56  м$^2$. Однако данные условия могут не выполняться для апартаментов и квартир-студий, поэтому во всех трех случаях видно небольшие "хвосты" ниже приведенных значений. Можно попробовать исключить апартаменты и студии и построить гистограмму для однокомнатных квартир, чтобы проверить данную гипотезу.

# %%
ax = (df
        .query('rooms == 1 and is_apartment == False and studio == False')
        .plot(y='total_area', 
              kind='hist', 
              bins=50, 
              range=(15, 60), 
              grid=True, 
              label='Однокомнатные')
     )

# %% [markdown]
# Даже в такой интерпретации видим небольшое количество значений ниже 28 м$^2$. Здесь нужно отметить, что в столбце 'is_apartment' пропущено больше 88% значений. При вносе данных о квартире необходимо сделать данный пункт обязательным. В таком случае можно ввести условие минимальной площади квартиры, если она не является апартаментами, и проверять не прошедшие проверку объявления на предмет мошеннических действий. При этом данные могут запрашиваться в автоматическом режиме по вводимому адресу квартиры.

# %% [markdown]
# Рассмотрим высоту потолков в квартирах. В первом пункте проекта было отмечено, что значения в столбце изменяются от 1 до 100 метров. Можно допустить высоту потолков до 10 метров, например- в жилых комплексах премиум- сегментав двухуровневых квартирах, но значение выше этого противоречит логике. Чтобы оценить количество выбросов, построим диаграмму размаха.

# %%
df.boxplot(column='ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим небольшое количество выбросов более 10 метров. Особенно интересна область от 20 до 35 метров- выглядит так, как будто при вводе данных люди ошибаются с положением точки, отделяющей целую часть от десятичной. Построим гистограмму для данного столбца.

# %%
df.hist(column='ceiling_height', bins=20, range=(2, 4))
# Out:
# array([[<AxesSubplot:title={'center':'ceiling_height'}>]], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Отличный анализ 👍🏻
#
# </div>

# %% [markdown]
# Видим,что значений меньше 2,5 метров крайне мало. Наличие пика в 2,5 м объясняется требованиями строительных норм (СП 54.13330.2016, п. 5.8), по которым высота потолка в жилых помещениях не может быть ниже 2,5 м. Высота потолка от 2 до 2,5 метров может быть объяснена расположением квартиры в здании исторической застройки. Значения меньше 2 следует отбросить. При анализе "хвоста" больше 4 метров видим небольшое количество значений до 8,5 метров и всего одно значение, равное 100. Значения больше 8,5 также отбросим.
#
# Отфильтруем данные следующим образом- отбросим данные, в которых площадь квартиры (не апартаментов и не студии) ниже минимальной, высота потолков меньше 2 и больше 8,5 метров, цена за квадратный метр в Санкт-Петербурге- не ниже 55 тысяч, в Ленинградской области- не ниже 10 тысяч, после чего посчитаем количество строк и построим новую гистограмму с ценой за квадратный метр, также разделяя квартиры в Санкт-Петербурге и Ленинградской области.

# %%
df_filtered = df.query('(rooms == 1 and total_area >= 28) or (rooms == 2 and total_area >= 44)  or (rooms > 2 and total_area >= 56) or (is_apartment == True or studio == True)')
df_filtered = df_filtered.query('2 <= ceiling_height <= 8.5')
df_filtered = df_filtered.query('(locality_name in ["Санкт-Петербург"] and meter_price >= 55000) or (meter_price >= 10000 and ["Санкт-Петербург"] not in locality_name)')
ax = (df_filtered
    .query('is_saintp == True')
    .plot(
    kind='hist',
    y='meter_price',
    histtype='step',
    range=(0, 250000),
    bins=50,
    linewidth=5,
    alpha=0.7,
    label='Санкт-Петербург',
))
(df_filtered
    .query('is_saintp == False')
    .plot(
    kind='hist',
    y='meter_price',
    histtype='step',
    range=(0, 250000),
    bins=50,
    linewidth=5,
    alpha=0.7,
    label='Ленинградская область',
    ax=ax,
    grid=True,
    legend=True,
) )
print(f'До фильтрации число строк в таблице составляло: {len(df)}, после фильтрации: {len(df_filtered)}, отфильтровано {(len(df) -len(df_filtered)) / len(df): .1%} строк.')
# Out:
# До фильтрации число строк в таблице составляло: 23699, после фильтрации: 22006, отфильтровано  7.1% строк.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Чистка супер, отлично объясняешь логику своих действий👍🏻
#
# </div>

# %% [markdown]
# В отфильтрованных данных изучим влияние количества комнат на цену квартиры. Для начала определим, какое количество комнат характерно для большинства квартир.

# %%
df_filtered.hist(column='rooms', bins=7, range=(0,7))
# Out:
# array([[<AxesSubplot:title={'center':'rooms'}>]], dtype=object)

# %% [markdown]
# Только квартиры, в которых от 1 до 4 комнат, встречаются более 1000 раз каждая. Квартиры с большим количеством комнат встречаются гораздо реже. Также есть небольшое количество квартир с нулевых количеством комнат. Судя по всему, это квартиры с открытой планировкой и студии. Изучим распределение цен в квартирах от 1 до 4 комнат.

# %%
df_filtered.query('0 < rooms < 5').pivot_table(index='rooms', values='last_price', aggfunc='median').plot.barh(grid=True)
# Out:
# <AxesSubplot:ylabel='rooms'>

# %% [markdown]
# Видим, что цена квартиры напрямую зависит от количества комнат. При этом видно, что линейная зависимость цены от количества комнат прослеживается только в интервале от 1 до 3, далее зависимость становится нелинейной, но данных по 4-комнатным квартирам намного меньше, чем по остальным, поэтому возможно отклонение. Здесь интересно будет также изучить влияние количества комнат на цену квадратного метра. Гипотеза следующая: цена квадратного метра в однокомнатных будет выше, чем в остальных, так как в однокомнатных квартирах больше доля жилой площади и меньше площади тратится на коридоры и прочие неиспользуемые пространства. Для начала проверим зависимость средней доли жилой площади от количества комнат, а затем- цену квадратного метра в зависимости от количества комнат.

# %%
df_filtered.query('0 < rooms < 5').pivot_table(index='rooms', values='living_ratio', aggfunc='median').plot.barh()
# Out:
# <AxesSubplot:ylabel='rooms'>

# %%
df_filtered.query('0 < rooms < 5').pivot_table(index='rooms', values='meter_price', aggfunc='median').plot.barh()
# Out:
# <AxesSubplot:ylabel='rooms'>

# %% [markdown]
# Гипотеза подтвердилась частично- цена квадратного метра в однокомнатных квартирах действительно выше, но доля жилой площади в них меньше. Следовательно, на цену квадратного метра влияет какой-то другой параметр. Возможно, спрос на однокомнатные квартиры выше, чем на все остальные. Проверим эту гипотезу в разделе с анализом времени продажи квартиры- если спрос на однокомнатные квартиры действительно выше, то и продаваться они в среднем будут быстрее.

# %%
df_filtered.corr()
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.102720    0.110329  0.100407
# last_price               0.102720    1.000000    0.654143  0.373494
# total_area               0.110329    0.654143    1.000000  0.778509
# rooms                    0.100407    0.373494    0.778509  1.000000
# ceiling_height           0.034888    0.249410    0.352860  0.237555
# floors_total             0.012190   -0.019212   -0.093016 -0.213675
# living_area              0.103640    0.543377    0.890117  0.838869
# floor                    0.029703    0.019103   -0.035190 -0.139659
# studio                  -0.031676   -0.027261   -0.077241 -0.150563
# open_plan               -0.013222    0.006934    0.003608  0.007579
# kitchen_area             0.107755    0.473351    0.595457  0.316834
# balcony                  0.044527    0.002221   -0.000123 -0.007673
# airports_nearest        -0.018109   -0.039365   -0.033203 -0.036762
# ...

# %% [markdown]
# В столбце 'last_price' видим среднюю корреляцию с общей площадью квартиры и сильную корреляцию с ценой квадратного метра, что логично- цена квадратного метра высчитывается из цены квартиры и общей площади. Также видим слабую корреляцию с жилой площадью и площадью кухни и очень слабую- с высотой потолка и количеством комнат. Изучим эти зависимости в виде графиков. Все площади и высота потолков имеют различное количество знаков после запятой, что несколько исказит общую картину при построении графиков, поэтому создадим отдельные столбцы, где округлим площади комнат до целых, а высоту потолков- до двух знаков после запятой, после чего построим графики зависимостей, пользуясь сводными таблицами.

# %%
df_filtered['total_rounded'] = df_filtered['total_area'].round()
df_filtered['living_rounded'] = df_filtered['living_area'].round()
df_filtered['kitchen_rounded'] = df_filtered['kitchen_area'].round()
df_filtered['ceiling_rounded'] = df_filtered['ceiling_height'].round(2)
(df_filtered
    .pivot_table(index='total_rounded', values='last_price', aggfunc='median')
    .plot(xlim=(0, 200), ylim=(0, 30000000)))
(df_filtered
    .pivot_table(index='kitchen_rounded', values='last_price', aggfunc='median')
    .plot(xlim=(0, 40), ylim=(0, 30000000)))
(df_filtered
    .pivot_table(index='living_rounded', values='last_price', aggfunc='median')
    .plot(xlim=(0, 100), ylim=(0, 30000000)))
(df_filtered
    .pivot_table(index='ceiling_rounded', values='last_price', aggfunc='median')
    .plot(xlim=(2.5, 3.5), ylim=(0, 20000000)))
# Out:
# <AxesSubplot:xlabel='ceiling_rounded'>

# %% [markdown]
# На всех графиках видим прямую зависимость цены от выбранного параметра. Стоит отметить, что общая и жилая площади и площадь кухни- взаимосвязанные параметры. Также цена зависит и от высоты потолков. Однако здесь стоит уточнить, зависит ли высота потолков от общей площади квартиры- небольшая высота потолков и маленькая площадь свойственны квартирам в старой застройке. Построим график зависимости высоты потолка от площади квартиры и проверим данную гипотезу.

# %%
(df_filtered
    .pivot_table(index='ceiling_rounded', values='total_rounded', aggfunc='mean')
    .plot(xlim=(2.5, 3.2), ylim=(0, 150)))
# Out:
# <AxesSubplot:xlabel='ceiling_rounded'>

# %% [markdown]
# Также определим влияние категории этажа на цену квадратного метра. Для этого построим три гистограммы распределения- для первого, последнего и другого этажей.

# %%
for name, grouped_data in df_filtered.loc[df_filtered['floor_type'] != 'неизвестно'].groupby('floor_type'):
    grouped_data.plot(y='meter_price', kind='hist', bins=50, range=(0, 200000), title=name)

# %% [markdown]
# По распределению видим, что медианная цена квадратного метра на первом и последнем этажах ниже, чем на любом другом- 80 и 85 тысяч рублей против 110, соответственно. Такой разброс цен закономерен- жить на первом этаже некомфортно, а рассматривая квартиру на последнем этаже, покупатели обычно боятся протекающей крыши и испорченного ремонта. Интересно отметить, что распределение на другом этаже близко к нормальному распределению, что нельзя сказать про первый и последний этажи- там левая часть перевешивает правую, что говорит о тенденции к большему занижению цены.
#
# Теперь изучим влияние удаленности от центра на цену квартиры. Для этого создадим столбец с округленным значением удаленности от центра в километрах.

# %%
df_filtered['rounded_distance'] = df_filtered['city_center_nearest'] / 1000
df_filtered['rounded_distance'] = df_filtered['rounded_distance'].round()
df_filtered.pivot_table(index='rounded_distance', values='meter_price', aggfunc='mean').plot()
# Out:
# <AxesSubplot:xlabel='rounded_distance'>

# %% [markdown]
# По графику видно снижение цены при удалении от центра Санкт-Петербурга, причем это справедливо даже для очень отдаленных локаций- дальше 120 км.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Все верно, графики и выводы верны 👍🏻
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Не хватает анализа зависимости цены и категории этажа
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_2
# Критично
#
# Анализ зависимости цены от категории этажа не добавлен проект
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправлено.
# </div>

# %% [markdown]
# При построении графика ограничились высотой потолков от 2,5 до 3,2 метра- это соответствует высоте потолков в домах массовой застройки. Здесь также видим прямую зависимость средней общей площади квартир от высоты потолков. Таким образом, гипотеза подтверждается- с ростом площади квартир, растет и высота потолков, поэтому все четыре показателя- площади общую, жилую и кухни и высоту потолков,- следует рассматривать совместно.

# %% [markdown]
# Изучим срок продажи квартир.

# %%
df_filtered.boxplot(column='days_exposition')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим большое количество выбросов выше 450 дней. Рассмотрим данные подробнее, построив гистограмму и изменяя диапазон значений и количество корзин.

# %%
df_filtered.hist(column='days_exposition', bins=50, range=(0,600))
df_filtered['days_exposition'].describe()
# Out:
# count    22006.000000
# mean       158.166545
# std        215.067149
# min         -1.000000
# 25%         23.000000
# 50%         75.000000
# 75%        201.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее время продажи квартиры- 158 дней, медиана- 75 дней. Такая разница среднего и медианы объясняется 'тяжелым хвостом' при анализе гистограммы- частных больших значений не так много, но они растянуты во времени. Видно выбивающиеся значения в районе 45, 60 и 90 дней. Следует уточнить, есть ли максимальный срок размещения объявления без его обновления. Выглядит так, как будто на 45, 60 или 90 день размещения в каких-то случаях объявления снимаются автоматически. Отсортируем данные и рассмотрим их подробнее.

# %%
df_filtered.query('days_exposition == 45').sample(10).transpose()
# Out:
#                                     6932                 7943   \
# total_images                            3                    0
# last_price                      2999000.0            3000000.0
# total_area                           57.0                 36.0
# first_day_exposition  2017-12-07 00:00:00  2018-02-01 00:00:00
# rooms                                   2                    1
# ceiling_height                   2.692151                  2.6
# floors_total                           12                    9
# living_area                     34.907861                 19.3
# floor                                   9                    8
# is_apartment                          NaN                  NaN
# studio                              False                False
# open_plan                           False                False
# kitchen_area                      8.58893                  7.0
# balcony                                 0                    2
# ...

# %% [markdown]
# Объявления не имеют никаких общих признаков, что говорит в пользу гипотезы об автоматическом удалении объявлений. Необходимо выявить причину удаления. Стоит также учесть, что в столбце 'days_exposition' было пропущено больше 3000 значений. Следует проверить ошибку сохранения данных в данном столбце. Рассмотрим, как менялся спрос на недвижимость по годам. Проверим гипотезу, что количество предложений на рынке постоянно растет за счет постоянного строительства как в черте города Санкт-Петербурга, так и за его пределами, а также в связи  с развитием информационных онлайн-сервисов по подбору недвижимости.

# %%
df_filtered.hist(column='exposition_year', bins=5)
# Out:
# array([[<AxesSubplot:title={'center':'exposition_year'}>]], dtype=object)

# %% [markdown]
# Как и ожидалось, видим взрывной рост, начиная с 2017 года.
#
# Проверим две гипотезы- срок размещения объявления зависит от месяца публикации и от месяца снятия объявления с продажи.

# %%
#создадим сводную таблицу с подсчетом медианного значения срока продажи квартиры и количеством объявлений по месяцам продажи,
#исключая значения -1, которыми заполнили пропуски в данных
df_sales_period = (df_filtered
                   .query('days_exposition not in [-1]')
                   .pivot_table(index='sales_month', values='days_exposition', aggfunc=['median', 'count']))
df_sales_period.columns = ['median', 'count']
#создадим сводную таблицу с подсчетом медианного значения срока продажи квартиры и количеством объявлений по месяцам покупки,
#исключая значения -1, которыми заполнили пропуски в данных
df_exposition_period = (df_filtered
                   .query('days_exposition not in [-1]')
                   .pivot_table(index='exposition_month', values='days_exposition', aggfunc=['median', 'count']))
df_exposition_period.columns = ['exp_median', 'exp_count']
#объединим таблицы
df_sales_period = df_sales_period.join(df_exposition_period)
#построим столбчатые диаграммы, объединяя попарно количество опубликованных и снятых объявлений по месяцам
#и медиану срока публикации в зависимости от месяца публикации и от месяца снятия
(df_sales_period
    .plot(y=['count', 'exp_count'], 
          kind='bar', 
          label=['снятых объявлений', 'опубликованных объявлений'], 
          title='количество', 
          figsize=(9, 4)))
(df_sales_period
    .plot(y='exp_median', 
          kind='bar', 
          label='опубликованных объявлений', 
          title='медиана', 
          figsize=(9, 4)))
# Out:
# <AxesSubplot:title={'center':'медиана'}, xlabel='sales_month'>

# %% [markdown]
# Анализируя графики, можем сделать следующий вывод: в январе, мае и декабре публикуется меньше всего объявлений. Это может быть связано с производственным календарем- в январе и мае много выходных дней и люди отдают предпочтение отдыху. При этом публикация объявлений имеет два ярко выраженных пика- в феврале и ноябре. Снятие объявлений с публикаций имеет ярко выраженное снижение в мае и июне- люди отдыхают на майских праздниках, а потом в отпуске. Начиная с июля снятие объявлений постепенно повышается и доходит до максимального значения почти в 2000 к апрелю, снижаясь только в феврале и декабре. Если рассмотреть второй график- зависимость медианного срока публикации объявления от месяца публикации или снятия, можно также увидеть зависимости- объявления, опубикованные в апреле и в мае, держатся на сайте намного дольше, чем объявления, опубликованные в любое другое время. Так, например, публикуя объявление в мае, будем ожидать, что оно пробудет на сайте в 1,5 раза дольше, чем объявление, опубликованное в ноябре.
#
# Также проверим, как распределяется публикация объявлений по дням недели.

# %%
df_filtered['weekday'].value_counts(sort=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Здесь видим, что по выходным публикуют в два раза меньше объявлений, чем в будни.

# %%
(df_filtered
    .pivot_table(index='exposition_year', values='last_price', aggfunc='median')
    .plot())
(df_filtered
    .pivot_table(index='exposition_month', values='last_price', aggfunc='median')
    .plot())
(df_filtered
    .pivot_table(index='weekday', values='last_price', aggfunc='median')
    .plot())
# Out:
# <AxesSubplot:xlabel='weekday'>

# %% [markdown]
# Построив графики зависимости медианы цен на квартиры от года, месяца и дня недели публикации можем сделать вывод, что цена зависит от года и месяца публикации. В 2014, 2015, 2016 годах было опубликовано мало объявлений, поэтому скачок на графике обусловлен небольшой выборкой. Начиная с 2017 года видим тенденцию на увеличение медианной цены квартиры. Зависимость от месяца также лучше изучать на графике медианы, а не среднего значения, так как он менее чувствителен к отдельным выбросам. По данному графику мы видим снижение цены квартиры в июне. В июне же публикуют меньше всего объявлений и покупают меньше всего квартир, поэтому и продают их по сниженной цене. Интересную особенность имеет график зависимости цены от дня недели- с понедельника по четверг цена квартир немного выше, чем с пятницы по воскресенье. Рассматривая графики зависимости количества объявлений и цены от дня недели, можем предположить, что в выходные объявления чаще выкладывают собственники квартир- в выходные у них освобождается время, чтобя сфотографировать квартиру и написать текст объявления, а в будни объявления чаще выкладывают риелторы, добавляя к цене квартиры от 100 до 175 тысяч рублей.
# В предыдущих разделах была сформулирована гипотеза, что количество комнат влияет на время продажи квартиры. Проверим ее.

# %%
df_filtered.query('0 < rooms < 5').pivot_table(index='rooms', values='days_exposition', aggfunc='median').plot.barh()
# Out:
# <AxesSubplot:ylabel='rooms'>

# %% [markdown]
# Действительно, чем больше в квартире комнат, тем выше цена и срок ее продажи. Высокий спрос на однокомнатные квартиры сформирован их небольшой ценой по сравнению с остальными, поэтому продаются они быстрее и стоят в пересчете на квадратный метр дороже.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Структура
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Не рекомендую смешивать шаги исследования, структура проекта нарушается. Лучше все по порядку. Зависимость цены от дат размещения другим этапом идет
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо за рекомендацию! Как раз не мог понять, что мне не нравится в структуре :) Перенес всё ниже.
# </div>

# %% [markdown]
# Выделим 10 самых больших населенных пунктов, посчитаем в них среднюю цену квадратного метра и выясним, где жилье дороже, а где- дешевле.

# %%
df_top10 = df_filtered.pivot_table(index='locality_name', values='meter_price', aggfunc=['count', 'mean'])
df_top10.columns = ['count', 'mean']
df_top10 = df_top10.sort_values(by='count', ascending=False)
df_top10 = df_top10.head(10)
df_top10.sort_values(by='mean', ascending=True).plot.barh(y='mean')
# Out:
# <AxesSubplot:ylabel='locality_name'>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Расчеты верны, но можно добавить визуализаций
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил линейчатую диаграмму к распределению цен в 10 крупных населенных пунктах
# </div>

# %% [markdown]
# Самая высокая цена квадратного метра- в Санкт-Петербурге. Дороже 90 тысяч за квадратный метр недвижимость также в Пушкине, Кудрово и поселке Парголово. Населенные пункты с самой низкой ценой- Гатчина, Всеволожск и, с большим отрывом, Выборг.
#
# Далее определим, как влияет удаленность от центра Санкт-Петербурга на цену квартиры, и какую удаленность можно называть 'центром'.

# %%
df_filtered.query('is_saintp == True').plot(x='city_center_nearest', y='meter_price', kind='scatter', alpha=0.1,  ylim=(0, 300000), xlim=(0, 30000))
# Out:
# <AxesSubplot:xlabel='city_center_nearest', ylabel='meter_price'>

# %% [markdown]
# В целом видим очень слабую корреляцию цены квадратного метра и расстояния от центра города, но наибольшее скопление квартир с ценой квадратного метра выше 200 тысяч рублей видим в зоне до 7 километров от центра города.
#
# Определим, как удаленность от центра влияет на цену квадатного метра. Для этого введем дополнительный столбец с удаленностью от центра, округленной до целого значения, после чего построим график изменения средней цены в зависимости от расстояния от центра города.

# %%
df_distance_price = (df_filtered
                         .query('is_saintp == True and rounded_distance >= 0')
                         .pivot_table(index='rounded_distance', 
                                      values=['last_price', 'meter_price'], 
                                      aggfunc=['mean', 'median', 'count']))
df_distance_price.columns = ['lastp_mean', 'meterp_mean', 'lastp_median', 'meterp_median', 'lastp_count', 'meterp_count']
grid = plt.GridSpec(3, 1, hspace=0.3)
ax1 = plt.subplot(grid[0, 0])
ax2 = plt.subplot(grid[1, 0])
ax3 = plt.subplot(grid[2, 0])
df_distance_price.plot(y=['lastp_mean', 'lastp_median'], grid=True, ax=ax1, figsize=(8, 12))

df_distance_price.plot(y=['meterp_mean', 'meterp_median'], grid=True, ax=ax2, figsize=(8, 12))

df_distance_price.plot(y=['lastp_count'], grid=True, ax=ax3, figsize=(8, 12))
# Out:
# <AxesSubplot:xlabel='rounded_distance'>

# %% [markdown]
# Судя по графикам, ранее сделанное предположение о том, что центр Санкт-Петербурга располагается не дальше 7 километров, подтверждается. Чем дальше от центра, тем ближе по значению среднее арифметическое и медиана, то есть разброс значений не такой большой, как в центре. Учитывая, что в центре Санкт-Петербурга много домов исторической застройки, можем предположить, что такой разброс цен объясняется состоянием жилья- от ветхого до элитного. Чем дальше от центра, тем меньше домов исторической застройки и, как следствие, не такая большая разница в состоянии ремонта. На расстоянии 3 км от центра видим снижение цены квартиры и цены квадратного метра. Судя по карте, в эту область входит Гутуевский остров- район вдалеке от станций метрополитена, вблизи промышленной застройки. Возможно, такая разница в цене объясняется данным фактом, однако более подробно изучить отклонение не представляется возможным- в датафрейме отсутствуют географические координаты квартир и близость к метро.
#
# Изучим подробнее квартиры в центре Санкт-Петербурга- не далее 7 км от центра. Для начала построим гистограммы цены квадратного метра, общей площади и высоты потолков.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Центральная граница определена верно 👍🏻
#
# </div>

# %%
(df_filtered
    .query('rounded_distance <= 7 and is_saintp == True')
    .hist(column='meter_price', bins=50, range=(50000, 300000)))
(df_filtered
    .query('rounded_distance <= 7 and is_saintp == True')
    .hist(column='total_area', bins=50, range=(0, 300)))
(df_filtered
    .query('rounded_distance <= 7 and is_saintp == True')
    .hist(column='ceiling_height', bins=10, range=(2.5, 4)))
# Out:
# array([[<AxesSubplot:title={'center':'ceiling_height'}>]], dtype=object)

# %% [markdown]
# Квартиры в центре отличаются от остальных- квартир дороже 120 тысяч за квадратный метр здесь больше, площадь квартир также превышает среднюю по городу, а потолки здесь выше, причем видно сразу два пика- на 2,7 м и на 3,1 м.
#
# Изучим количество комнат в квартирах в центре и вне центра.

# %%
grid = plt.GridSpec(1, 2, wspace=0.4)
ax1 = plt.subplot(grid[0, 0])
ax2 = plt.subplot(grid[0, 1])
(df_filtered
    .query('rounded_distance <= 7 and is_saintp == True')
    .plot(y='rooms', 
          kind='hist', 
          bins=6, 
          range=(1, 7), 
          ax=ax1, 
          grid=True,  
          figsize=(10,4), 
          title='в центре'))
(df_filtered
    .query('rounded_distance > 7 and is_saintp == True')
    .plot(y='rooms', 
          kind='hist', 
          bins=6, 
          range=(1, 7), 
          ax=ax2, 
          grid=True,  
          figsize=(10,4), 
          title='вне центра'))
# Out:
# <AxesSubplot:title={'center':'вне центра'}, ylabel='Frequency'>

# %% [markdown]
# Здесь также видим отличие- квартиры вне центра в основном имеют от 1 до 3 комнат, причем однокомнатных больше всего, а квартиры в центре в подавляющем большинстве- двух- и трехкомнатные. Однокомнатных квартир в два раза меньше, чем двухкомнатных, и столько же, сколько и четырехкомнатных. Вне центра четырехкомнатных квартир очень мало.
#
# Далее определим влияние столбцов с буллевыми и категориальными параметрами на цену квадратного метра- наличия вблизи мест для прогулки и аэропорта, свободной планировки и этажа, на котором находится квартира.

# %%
df_bullean_price = df_filtered.pivot_table(index= ['is_saintp', 'is_walk'], values='meter_price', aggfunc='mean')
df_bullean_price
# Out:
#                      meter_price
# is_saintp is_walk
# False     False     66120.888384
#           True      87667.261356
# True      False    107177.901002
#           True     119262.156513

# %% [markdown]
# Здесь видим, что наличие поблизости от квартиры места для прогулок на свежем воздухе- парка или пруда, влияет на цену квадратного метра- в Ленинградской области она возрастает в среднем на 30%, а в Санкт- Петербурге- на 11%.

# %%
df_bullean_price = df_filtered.pivot_table(index= ['is_saintp', 'is_airport'], values='meter_price', aggfunc='mean')
df_bullean_price
# Out:
#                         meter_price
# is_saintp is_airport
# False     False        78002.563622
#           True         50805.919644
# True      False       115567.889269
#           True        119519.098028

# %% [markdown]
# Здесь видим интересную зависимость- наличие аэропорта вблизи населенного пункта Ленинградской области существенно снижает цену квадратного метра- с 78 до 51 тысячи. Скорее всего, это связано с шумовым загрязнением и, как следствие, меньшей привлекательностью таких квартир. На цену же квадратного метра в Санкт-Петербурге наличие аэропорта практически не влияет- разница между значениями всего 3%. Это может быть вызвано не столько наличием аэропорта, сколько другими параметрами.
#
# Проверим еще одну гипотезу- для квартир в центре Санкт-Петербурга влияние параметров будет иным по сравнению с остальными квартирами.

# %%
df_floor_price = df_filtered.query('floor_type not in "неизвестно"').pivot_table(index=['is_saintp', 'floor_type'], values='meter_price', aggfunc=['median', 'mean'])
df_floor_price.columns = ['median', 'mean']
df_floor_price
# Out:
#                              median           mean
# is_saintp floor_type
# False     другой       73386.086039   73575.888007
#           первый       60000.000000   60643.501659
#           последний    61764.705882   63524.361789
# True      другой      107229.426223  117141.290372
#           первый       93548.387097  101048.912547
#           последний   103081.837017  117838.637426

# %% [markdown]
# Расположение квартиры на первом этаже однозначно снижает ее стоимость как в Санкт-Петербурге, так и в Ленинградской области. В ленинградской области также снижается цена квадратного метра в квартирах на последнем этаже- покупатели часто боятся протечек с крыши. В Санкт-Петербурге ситуация иная- медиана цены квадратного метра на последнем этаже ниже цены на любом другом этаже, кроме первого- 103 тысячи против 107. Однако среднее значение в категориях 'другой' и 'последний' практически равны. Возможно, на смещение среднего влияют пентхаусы в премиум-сегменте жилья в черте города. Предполагая, что в жилье премиум-сегмента общая площадь выше, чем в остальных квартирах, построим две диаграммы- для общей площади во всех квартирах Санкт-Петербурга и отдельно- к квартирах на последних этажах.

# %%
df_filtered.query('is_saintp == True').hist(column='total_area', range=(0, 300), bins=25)
df_filtered.query('is_saintp == True and "последний" in floor_type').hist(column='total_area', range=(0, 300), bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %% [markdown]
# Видим, что в общем списке преобладают квартиры с небольшой площадью- до 48 м$^2$. Их количество настолько велико, что на распределении отчетливо виден пик. В квартирах на последних этажах распределение более сглаженное- пик не настолько выделяется из общего распределения. Однако видим повышение количества квартир с площадью больше 120 м$^2$, которого нет на общем распределении. Это говорит в пользу гипотезы- в черте города на последних этажах чаще размещаются квартиры премиум-сегмента с большой площадью и, как следствие, ценой.

# %%
df_saintp_center= df_filtered.query('is_saintp == True and 0 < city_center_nearest < 7000')
df_saintp_center.corr()
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.135277    0.092521  0.045488
# last_price               0.135277    1.000000    0.606476  0.307285
# total_area               0.092521    0.606476    1.000000  0.731160
# rooms                    0.045488    0.307285    0.731160  1.000000
# ceiling_height           0.093499    0.144706    0.269625  0.238433
# floors_total            -0.047200    0.041204   -0.026581 -0.185745
# living_area              0.079263    0.472859    0.847498  0.792414
# floor                   -0.009932    0.117720    0.099865 -0.041376
# studio                  -0.026077   -0.023343   -0.055279 -0.117268
# open_plan               -0.013420   -0.006620   -0.006386  0.010259
# kitchen_area             0.134393    0.426361    0.528811  0.282269
# balcony                  0.021589    0.076300    0.011200 -0.077653
# airports_nearest         0.013580    0.094195    0.024882 -0.081798
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Молодец, что проводишь дополнительный анализ 👍🏻
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Нет анализа факторов влиящих на цену, обозначенных в задании к проекту, их надо исследовать. Одной корреляции недостаточно, нужны визуализацтт
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_2
# Критично
#
# Этот комментарий не отработан, надо рассмотреть влияние следующих факторов на цену квартиры:
#
# - Число комнат
# - Удаленность от центра
# - Даты размещения объявления (год, месяц, день недели)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Максим, еще раз прошу прощения за неактуальную версию проекта. Поправил проект в соответствии с твоими замечаниями. Большое спасибо за рекомендации и советы!
# </div>

# %% [markdown]
# ### Вывод
#
# В данном разделе произведен исследовательский анализ данных. Выявлены зависимости параметров на цену квартир как по всему датафрейму, так и отдельно по городу Санкт-Петербургу. О влиянии параметров в общем можно сделать следующие выводы:
# 1) Наибольшее влияние на цену квартиры оказывают ее площадь, высота потолков и этаж расположения, причем зависимость цены от высоты потолков и площади квартиры прямо пропорциональна. Высота потолков в квартирах разная- в центре Санкт-Петербурга потолки выше, а по всему остальному городу и за его пределами высота потолков едва превышает минимальную, разрешенную строительными нормами. То же самое касается и площади- в центре Санкт-Петербурга площадь квартир больше, чем за его пределами. В основном, площадь квартир лишь немного выше минимальной площади, допустимой строительными нормами. Этаж, на котором располагается квартира, также имеет большое значение. Квартиры на первом этаже чаще всего дешевле на 10-20%. Про последний этаж нельзя сказать так однозначно- в основном, такие квартиры дешевле, но в черте города Санкт-Петербурга встречаются квартиры на последних этажах с большой площадью и ценой выше средней. Судя по всему, это квартиры премиум-сегмента и позиционируются как пентхаусы.
#
# 2) Однокомнатные квартиры продаются быстрее, а цена квадратного метра в них выше, чем в остальных квартирах. Высокий спрос сформирован низкой ценой на эти квартиры- в среднем они дешевле на 30%, чем двухкомнатные.
#
# 3) Расположение квартиры относительно центра Санкт-Петербурга оказывает сильное влияние на цену квартиры, причем даже в населенных пунктах Ленинградской области, иногда достаточно отдаленных- дальше 120 км. В самом Санкт-Петербурге наиболее высокие цены- в радиусе 7 км от центра, при этом цена также снижается при отдалении от него.
#
# 4) Если рассматривать близость квартиры к какому-либо социальному объекту, то можно сделать следующий вывод- цена квартиры зависит от наличия природных объектов вблизи нее- прудов или парков. Причем за пределами Санкт-Петербурга наличие такого объекта повышает цену квартиры на 30%. Наличие аэропорта вблизи либо никак не влияет, либо влияет в отрицательную сторону- в самом Санкт-Петербурге цена в зависимости от наличия аэропорта поблизости не меняется, а за его пределами- падает.
#
# 5) Цена квартиры зависит также и от месяца публикации объявления- в июне наблюдается спад как публикаций, так и снятия объявлений. Данный спад может объясняться отпуском у большого числа жителей. Объявления реже публикуют в выходные, а средняя цена квартиры в выходные снижается на 100-175 тысяч рублей. Вероятнее всего, в выходные объявления чаще публикуют собственники квартир, а в будни- риелторы. Более высокая цена квартир в таком случае объясняется их комиссией за услуги по продаже.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# По результатам работы над проектом можно сделать следующие выводы:
# 1) Необходимо обратить внимание на сохранение данных в некоторых столбцах. В некоторых столбцах пропущены данные. Их можно добавлять как в автоматическом режиме по введенному адресу как, например, высота потолка, ближайший парк и т.д., так и в ручном режиме- оставляя строки для введения обязательными для заполнения, как в случае с апартаментами. Некоторые данные для исследования отсутствуют совсем- необходимо добавить столбцы с информацией о расстоянии до ближайшей станции метрополитена и до объектов социальной инфраструктуры- школ, детских садов и т.д. В таком большом городе, как Санкт-Петербург, данная информация может быть решающей при покупке квартиры.
#
# 2) При предобработке данных не во всех столбцах получилось заполнить пропуски. Пропуски были заполнены либо основываясь на различных данных- одинаковые площади в типовых квартирах и т.п., либо отрицательными значениями, чтобы отделить их при анализе.
#
# 3) При выполнении исследовательского анализа данных были выявлены основные параметры, влияющие на цену квартиры. Цена квартиры зависит от различных параметров, но в основном- это площадь, высота потолков и расположение квартиры.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Отличные структурированные выводы 👍🏻
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
